# %%
import os
os.environ['HTTP_PROXY'] = "http://127.0.0.1:10809"
os.environ['HTTPS_PROXY'] = "http://127.0.0.1:10809"

# %%
import geemap
import ee
Map=geemap.Map()
Map
# Out:
# *** Earth Engine *** FINAL DEADLINE: ee.Authenticate will fail after 2022-06-06. Please upgrade. https://developers.google.com/earth-engine/guides/python_install
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %%
## 大庆市
# roi = ee.Geometry.Rectangle([123.9355, 45.8362,125.3055, 46.8762])
## 天津市
# roi = ee.Geometry.Rectangle([115.9244, 38.6272,117.4944,39.6372])
## 武汉市
roi = ee.Geometry.Rectangle([113.7393, 29.8642,115.0993, 30.9242])
## 珠三角
# roi = ee.Geometry.Rectangle([112.7614, 22.2347,114.0514, 23.2547])
## 青藏高原
# roi = ee.Geometry.Rectangle([89.8826, 34.6579,91.3626, 35.8279])
Map.addLayer(roi, {}, "roi")
Map.centerObject(roi,7)

# %%
vis = {'min': 0,'max': 2,'palette':['#FFFFFF','#87CEFA','#0000FF']}
re = [115.0993, 29.8642, 113.7393, 30.9242]
basemap = ee.Image.constant(0).clip(ee.Geometry.Rectangle(re)).rename('waterclass')
frequency = ee.Image('users/311605001111/JRC/' + 'JRC_' + 'wuhan' + '_9920')
permanent = frequency.gte(0.75).remap([0,1],[0,2]).rename('waterclass')
season= ee.ImageCollection([frequency.gte(0.25),frequency.lt(0.75)]).sum().eq(2).rename('waterclass')
pw = ee.ImageCollection([permanent,season,basemap]).sum().visualize(**vis)
Map.addLayer(pw,{},'pw')

# %% [markdown]
# # daqing

# %%
# 有效像元
image99 = ee.Image("users/311605001111/WP-VP/daqing_VP_1999").float()
image0 = ee.Image("users/311605001111/WP-VP/daqing_VP_2000").float()
image1 = ee.Image("users/311605001111/WP-VP/daqing_VP_2001").float()
image2 = ee.Image("users/311605001111/WP-VP/daqing_VP_2002").float()
image3 = ee.Image("users/311605001111/WP-VP/daqing_VP_2003").float()
image4 = ee.Image("users/311605001111/WP-VP/daqing_VP_2004").float()
image5 = ee.Image("users/311605001111/WP-VP/daqing_VP_2005").float()
image6 = ee.Image("users/311605001111/WP-VP/daqing_VP_2006").float()
image7 = ee.Image("users/311605001111/WP-VP/daqing_VP_2007").float()
image8 = ee.Image("users/311605001111/WP-VP/daqing_VP_2008").float()
image9 = ee.Image("users/311605001111/WP-VP/daqing_VP_2009").float()
image10 = ee.Image("users/311605001111/WP-VP/daqing_VP_2010").float()
image11 = ee.Image("users/311605001111/WP-VP/daqing_VP_2011").float()
image12 = ee.Image("users/311605001111/WP-VP/daqing_VP_2012").float()
image13 = ee.Image("users/311605001111/WP-VP/daqing_VP_2013").float()
image14 = ee.Image("users/311605001111/WP-VP/daqing_VP_2014").float()
image15 = ee.Image("users/311605001111/WP-VP/daqing_VP_2015").float()
image16 = ee.Image("users/311605001111/WP-VP/daqing_VP_2016").float()
image17 = ee.Image("users/311605001111/WP-VP/daqing_VP_2017").float()
image18 = ee.Image("users/311605001111/WP-VP/daqing_VP_2018").float()
image19 = ee.Image("users/311605001111/WP-VP/daqing_VP_2019").float()
image20 = ee.Image("users/311605001111/WP-VP/daqing_VP_2020").float()

validPixel = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12,image13,image14,image15,image16,image17,image18,image19,image20]).sum()
validPixel13 = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12]).sum()
validPixel8 = ee.ImageCollection([image13,image14,image15,image16,image17,image18,image19,image20]).sum()

# %%
# 水体像元
image99 = ee.Image("users/311605001111/WP-VP/daqing_WP_1999").float()
image0 = ee.Image("users/311605001111/WP-VP/daqing_WP_2000").float()
image1 = ee.Image("users/311605001111/WP-VP/daqing_WP_2001").float()
image2 = ee.Image("users/311605001111/WP-VP/daqing_WP_2002").float()
image3 = ee.Image("users/311605001111/WP-VP/daqing_WP_2003").float()
image4 = ee.Image("users/311605001111/WP-VP/daqing_WP_2004").float()
image5 = ee.Image("users/311605001111/WP-VP/daqing_WP_2005").float()
image6 = ee.Image("users/311605001111/WP-VP/daqing_WP_2006").float()
image7 = ee.Image("users/311605001111/WP-VP/daqing_WP_2007").float()
image8 = ee.Image("users/311605001111/WP-VP/daqing_WP_2008").float()
image9 = ee.Image("users/311605001111/WP-VP/daqing_WP_2009").float()
image10 = ee.Image("users/311605001111/WP-VP/daqing_WP_2010").float()
image11 = ee.Image("users/311605001111/WP-VP/daqing_WP_2011").float()
image12 = ee.Image("users/311605001111/WP-VP/daqing_WP_2012").float()
image13 = ee.Image("users/311605001111/WP-VP/daqing_WP_2013").float()
image14 = ee.Image("users/311605001111/WP-VP/daqing_WP_2014").float()
image15 = ee.Image("users/311605001111/WP-VP/daqing_WP_2015").float()
image16 = ee.Image("users/311605001111/WP-VP/daqing_WP_2016").float()
image17 = ee.Image("users/311605001111/WP-VP/daqing_WP_2017").float()
image18 = ee.Image("users/311605001111/WP-VP/daqing_WP_2018").float()
image19 = ee.Image("users/311605001111/WP-VP/daqing_WP_2019").float()
image20 = ee.Image("users/311605001111/WP-VP/daqing_WP_2020").float()

waterPixel = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12,image13,image14,image15,image16,image17,image18,image19,image20]).sum()
waterPixel13 = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12]).sum()
waterPixel8 = ee.ImageCollection([image13,image14,image15,image16,image17,image18,image19,image20]).sum()

# %%
# # 大庆市
roi = ee.Geometry.Rectangle([123.9355, 45.8362,125.3055, 46.8762])
# # 天津市
# roi = ee.Geometry.Rectangle([115.9244, 38.6272,117.4944,39.6372])
# # 武汉市
# roi = ee.Geometry.Rectangle([113.7393, 29.8642,115.0993, 30.9242])
# # 珠三角
# roi = ee.Geometry.Rectangle([112.7614, 22.2347,114.0514, 23.2547])
# 青藏高原
# roi = ee.Geometry.Rectangle([89.8826, 34.6579,91.3626, 35.8279])
Map.addLayer(roi, {}, "roi")
Map.centerObject(roi,7)

# %%
waterfrequency = waterPixel.divide(validPixel).rename('frequency')
Map.addLayer(waterfrequency,{'palette':['white','green'],'min':0,'max':1},"water frequency")

dataset_id = 'daqing_WF_' + '9920'
assetID = 'users/311605001111/WF/' + dataset_id
task = ee.batch.Export.image.toAsset(**{
    'image': waterfrequency,
    'description': dataset_id,
    'assetId': assetID,
    'scale': 30,
    'region': roi,
    'maxPixels': 1e13,
})
task.start()

# %% [markdown]
# # tianjin

# %%
# 有效像元
image99 = ee.Image("users/311605001111/WP-VP/tianjin_VP_1999").float()
image0 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2000").float()
image1 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2001").float()
image2 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2002").float()
image3 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2003").float()
image4 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2004").float()
image5 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2005").float()
image6 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2006").float()
image7 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2007").float()
image8 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2008").float()
image9 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2009").float()
image10 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2010").float()
image11 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2011").float()
image12 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2012").float()
image13 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2013").float()
image14 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2014").float()
image15 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2015").float()
image16 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2016").float()
image17 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2017").float()
image18 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2018").float()
image19 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2019").float()
image20 = ee.Image("users/311605001111/WP-VP/tianjin_VP_2020").float()

validPixel = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12,image13,image14,image15,image16,image17,image18,image19,image20]).sum()
validPixel13 = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12]).sum()
validPixel8 = ee.ImageCollection([image13,image14,image15,image16,image17,image18,image19,image20]).sum()

# %%
# 水体像元
image99 = ee.Image("users/311605001111/WP-VP/tianjin_WP_1999").float()
image0 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2000").float()
image1 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2001").float()
image2 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2002").float()
image3 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2003").float()
image4 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2004").float()
image5 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2005").float()
image6 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2006").float()
image7 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2007").float()
image8 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2008").float()
image9 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2009").float()
image10 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2010").float()
image11 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2011").float()
image12 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2012").float()
image13 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2013").float()
image14 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2014").float()
image15 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2015").float()
image16 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2016").float()
image17 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2017").float()
image18 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2018").float()
image19 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2019").float()
image20 = ee.Image("users/311605001111/WP-VP/tianjin_WP_2020").float()

waterPixel = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12,image13,image14,image15,image16,image17,image18,image19,image20]).sum()
waterPixel13 = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12]).sum()
waterPixel8 = ee.ImageCollection([image13,image14,image15,image16,image17,image18,image19,image20]).sum()

# %%
# # 大庆市
# roi = ee.Geometry.Rectangle([123.9355, 45.8362,125.3055, 46.8762])
# # 天津市
roi = ee.Geometry.Rectangle([115.9244, 38.6272,117.4944,39.6372])
# # 武汉市
# roi = ee.Geometry.Rectangle([113.7393, 29.8642,115.0993, 30.9242])
# # 珠三角
# roi = ee.Geometry.Rectangle([112.7614, 22.2347,114.0514, 23.2547])
# 青藏高原
# roi = ee.Geometry.Rectangle([89.8826, 34.6579,91.3626, 35.8279])
Map.addLayer(roi, {}, "roi")
Map.centerObject(roi,7)

# %%
waterfrequency = waterPixel.divide(validPixel).rename('frequency')
Map.addLayer(waterfrequency,{'palette':['white','green'],'min':0,'max':1},"water frequency")

dataset_id = 'tianjin_WF_' + '9920'
assetID = 'users/311605001111/WF/' + dataset_id
task = ee.batch.Export.image.toAsset(**{
    'image': waterfrequency,
    'description': dataset_id,
    'assetId': assetID,
    'scale': 30,
    'region': roi,
    'maxPixels': 1e13,
})
task.start()

# %% [markdown]
# # wuhan

# %%
# 有效像元
image99 = ee.Image("users/311605001111/WP-VP/wuhan_VP_1999").float()
image0 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2000").float()
image1 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2001").float()
image2 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2002").float()
image3 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2003").float()
image4 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2004").float()
image5 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2005").float()
image6 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2006").float()
image7 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2007").float()
image8 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2008").float()
image9 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2009").float()
image10 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2010").float()
image11 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2011").float()
image12 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2012").float()
image13 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2013").float()
image14 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2014").float()
image15 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2015").float()
image16 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2016").float()
image17 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2017").float()
image18 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2018").float()
image19 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2019").float()
image20 = ee.Image("users/311605001111/WP-VP/wuhan_VP_2020").float()

validPixel = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12,image13,image14,image15,image16,image17,image18,image19,image20]).sum()
validPixel13 = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12]).sum()
validPixel8 = ee.ImageCollection([image13,image14,image15,image16,image17,image18,image19,image20]).sum()

# %%
# 水体像元
image99 = ee.Image("users/311605001111/WP-VP/wuhan_WP_1999").float()
image0 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2000").float()
image1 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2001").float()
image2 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2002").float()
image3 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2003").float()
image4 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2004").float()
image5 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2005").float()
image6 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2006").float()
image7 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2007").float()
image8 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2008").float()
image9 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2009").float()
image10 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2010").float()
image11 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2011").float()
image12 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2012").float()
image13 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2013").float()
image14 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2014").float()
image15 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2015").float()
image16 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2016").float()
image17 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2017").float()
image18 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2018").float()
image19 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2019").float()
image20 = ee.Image("users/311605001111/WP-VP/wuhan_WP_2020").float()

waterPixel = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12,image13,image14,image15,image16,image17,image18,image19,image20]).sum()
waterPixel13 = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12]).sum()
waterPixel8 = ee.ImageCollection([image13,image14,image15,image16,image17,image18,image19,image20]).sum()

# %%
# # 大庆市
# roi = ee.Geometry.Rectangle([123.9355, 45.8362,125.3055, 46.8762])
# # 天津市
# roi = ee.Geometry.Rectangle([115.9244, 38.6272,117.4944,39.6372])
# # 武汉市
roi = ee.Geometry.Rectangle([113.7393, 29.8642,115.0993, 30.9242])
# # 珠三角
# roi = ee.Geometry.Rectangle([112.7614, 22.2347,114.0514, 23.2547])
# 青藏高原
# roi = ee.Geometry.Rectangle([89.8826, 34.6579,91.3626, 35.8279])
Map.addLayer(roi, {}, "roi")
Map.centerObject(roi,7)

# %%
waterfrequency = waterPixel.divide(validPixel).rename('frequency')
Map.addLayer(waterfrequency,{'palette':['white','green'],'min':0,'max':1},"water frequency")

dataset_id = 'wuhan_WF_' + '9920'
assetID = 'users/311605001111/WF/' + dataset_id
task = ee.batch.Export.image.toAsset(**{
    'image': waterfrequency,
    'description': dataset_id,
    'assetId': assetID,
    'scale': 30,
    'region': roi,
    'maxPixels': 1e13,
})
task.start()

# %% [markdown]
# # prd

# %%
# 有效像元
image99 = ee.Image("users/311605001111/WP-VP/prd_VP_1999").float()
image0 = ee.Image("users/311605001111/WP-VP/prd_VP_2000").float()
image1 = ee.Image("users/311605001111/WP-VP/prd_VP_2001").float()
image2 = ee.Image("users/311605001111/WP-VP/prd_VP_2002").float()
image3 = ee.Image("users/311605001111/WP-VP/prd_VP_2003").float()
image4 = ee.Image("users/311605001111/WP-VP/prd_VP_2004").float()
image5 = ee.Image("users/311605001111/WP-VP/prd_VP_2005").float()
image6 = ee.Image("users/311605001111/WP-VP/prd_VP_2006").float()
image7 = ee.Image("users/311605001111/WP-VP/prd_VP_2007").float()
image8 = ee.Image("users/311605001111/WP-VP/prd_VP_2008").float()
image9 = ee.Image("users/311605001111/WP-VP/prd_VP_2009").float()
image10 = ee.Image("users/311605001111/WP-VP/prd_VP_2010").float()
image11 = ee.Image("users/311605001111/WP-VP/prd_VP_2011").float()
image12 = ee.Image("users/311605001111/WP-VP/prd_VP_2012").float()
image13 = ee.Image("users/311605001111/WP-VP/prd_VP_2013").float()
image14 = ee.Image("users/311605001111/WP-VP/prd_VP_2014").float()
image15 = ee.Image("users/311605001111/WP-VP/prd_VP_2015").float()
image16 = ee.Image("users/311605001111/WP-VP/prd_VP_2016").float()
image17 = ee.Image("users/311605001111/WP-VP/prd_VP_2017").float()
image18 = ee.Image("users/311605001111/WP-VP/prd_VP_2018").float()
image19 = ee.Image("users/311605001111/WP-VP/prd_VP_2019").float()
image20 = ee.Image("users/311605001111/WP-VP/prd_VP_2020").float()

validPixel = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12,image13,image14,image15,image16,image17,image18,image19,image20]).sum()
validPixel13 = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12]).sum()
validPixel8 = ee.ImageCollection([image13,image14,image15,image16,image17,image18,image19,image20]).sum()

# %%
# 水体像元
image99 = ee.Image("users/311605001111/WP-VP/prd_WP_1999").float()
image0 = ee.Image("users/311605001111/WP-VP/prd_WP_2000").float()
image1 = ee.Image("users/311605001111/WP-VP/prd_WP_2001").float()
image2 = ee.Image("users/311605001111/WP-VP/prd_WP_2002").float()
image3 = ee.Image("users/311605001111/WP-VP/prd_WP_2003").float()
image4 = ee.Image("users/311605001111/WP-VP/prd_WP_2004").float()
image5 = ee.Image("users/311605001111/WP-VP/prd_WP_2005").float()
image6 = ee.Image("users/311605001111/WP-VP/prd_WP_2006").float()
image7 = ee.Image("users/311605001111/WP-VP/prd_WP_2007").float()
image8 = ee.Image("users/311605001111/WP-VP/prd_WP_2008").float()
image9 = ee.Image("users/311605001111/WP-VP/prd_WP_2009").float()
image10 = ee.Image("users/311605001111/WP-VP/prd_WP_2010").float()
image11 = ee.Image("users/311605001111/WP-VP/prd_WP_2011").float()
image12 = ee.Image("users/311605001111/WP-VP/prd_WP_2012").float()
image13 = ee.Image("users/311605001111/WP-VP/prd_WP_2013").float()
image14 = ee.Image("users/311605001111/WP-VP/prd_WP_2014").float()
image15 = ee.Image("users/311605001111/WP-VP/prd_WP_2015").float()
image16 = ee.Image("users/311605001111/WP-VP/prd_WP_2016").float()
image17 = ee.Image("users/311605001111/WP-VP/prd_WP_2017").float()
image18 = ee.Image("users/311605001111/WP-VP/prd_WP_2018").float()
image19 = ee.Image("users/311605001111/WP-VP/prd_WP_2019").float()
image20 = ee.Image("users/311605001111/WP-VP/prd_WP_2020").float()

waterPixel = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12,image13,image14,image15,image16,image17,image18,image19,image20]).sum()
waterPixel13 = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12]).sum()
waterPixel8 = ee.ImageCollection([image13,image14,image15,image16,image17,image18,image19,image20]).sum()

# %%
# # 大庆市
# roi = ee.Geometry.Rectangle([123.9355, 45.8362,125.3055, 46.8762])
# # 天津市
# roi = ee.Geometry.Rectangle([115.9244, 38.6272,117.4944,39.6372])
# # 武汉市
# roi = ee.Geometry.Rectangle([113.7393, 29.8642,115.0993, 30.9242])
# # 珠三角
roi = ee.Geometry.Rectangle([112.7614, 22.2347,114.0514, 23.2547])
# 青藏高原
# roi = ee.Geometry.Rectangle([89.8826, 34.6579,91.3626, 35.8279])
Map.addLayer(roi, {}, "roi")
Map.centerObject(roi,7)

# %%
waterfrequency = waterPixel.divide(validPixel).rename('frequency')
Map.addLayer(waterfrequency,{'palette':['white','green'],'min':0,'max':1},"water frequency")

dataset_id = 'prd_WF_' + '9920'
assetID = 'users/311605001111/WF/' + dataset_id
task = ee.batch.Export.image.toAsset(**{
    'image': waterfrequency,
    'description': dataset_id,
    'assetId': assetID,
    'scale': 30,
    'region': roi,
    'maxPixels': 1e13,
})
task.start()

# %% [markdown]
# # tibet

# %%
# 有效像元
image99 = ee.Image("users/311605001111/WP-VP/tibet_VP_1999")
image0 = ee.Image("users/311605001111/WP-VP/tibet_VP_2000")
image1 = ee.Image("users/311605001111/WP-VP/tibet_VP_2001")
image2 = ee.Image("users/311605001111/WP-VP/tibet_VP_2002")
image3 = ee.Image("users/311605001111/WP-VP/tibet_VP_2003")
image4 = ee.Image("users/311605001111/WP-VP/tibet_VP_2004")
image5 = ee.Image("users/311605001111/WP-VP/tibet_VP_2005")
image6 = ee.Image("users/311605001111/WP-VP/tibet_VP_2006")
image7 = ee.Image("users/311605001111/WP-VP/tibet_VP_2007")
image8 = ee.Image("users/311605001111/WP-VP/tibet_VP_2008")
image9 = ee.Image("users/311605001111/WP-VP/tibet_VP_2009")
image10 = ee.Image("users/311605001111/WP-VP/tibet_VP_2010")
image11 = ee.Image("users/311605001111/WP-VP/tibet_VP_2011")
image12 = ee.Image("users/311605001111/WP-VP/tibet_VP_2012")
image13 = ee.Image("users/311605001111/WP-VP/tibet_VP_2013")
image14 = ee.Image("users/311605001111/WP-VP/tibet_VP_2014")
image15 = ee.Image("users/311605001111/WP-VP/tibet_VP_2015")
image16 = ee.Image("users/311605001111/WP-VP/tibet_VP_2016")
image17 = ee.Image("users/311605001111/WP-VP/tibet_VP_2017")
image18 = ee.Image("users/311605001111/WP-VP/tibet_VP_2018")
image19 = ee.Image("users/311605001111/WP-VP/tibet_VP_2019")
image20 = ee.Image("users/311605001111/WP-VP/tibet_VP_2020")

validPixel = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12,image13,image14,image15,image16,image17,image18,image19,image20]).sum()
validPixel13 = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12]).sum()
validPixel8 = ee.ImageCollection([image13,image14,image15,image16,image17,image18,image19,image20]).sum()

# %%
# 水体像元
image99 = ee.Image("users/311605001111/WP-VP/tibet_WP_1999")
image0 = ee.Image("users/311605001111/WP-VP/tibet_WP_2000")
image1 = ee.Image("users/311605001111/WP-VP/tibet_WP_2001")
image2 = ee.Image("users/311605001111/WP-VP/tibet_WP_2002")
image3 = ee.Image("users/311605001111/WP-VP/tibet_WP_2003")
image4 = ee.Image("users/311605001111/WP-VP/tibet_WP_2004")
image5 = ee.Image("users/311605001111/WP-VP/tibet_WP_2005")
image6 = ee.Image("users/311605001111/WP-VP/tibet_WP_2006")
image7 = ee.Image("users/311605001111/WP-VP/tibet_WP_2007")
image8 = ee.Image("users/311605001111/WP-VP/tibet_WP_2008")
image9 = ee.Image("users/311605001111/WP-VP/tibet_WP_2009")
image10 = ee.Image("users/311605001111/WP-VP/tibet_WP_2010")
image11 = ee.Image("users/311605001111/WP-VP/tibet_WP_2011")
image12 = ee.Image("users/311605001111/WP-VP/tibet_WP_2012")
image13 = ee.Image("users/311605001111/WP-VP/tibet_WP_2013")
image14 = ee.Image("users/311605001111/WP-VP/tibet_WP_2014")
image15 = ee.Image("users/311605001111/WP-VP/tibet_WP_2015")
image16 = ee.Image("users/311605001111/WP-VP/tibet_WP_2016")
image17 = ee.Image("users/311605001111/WP-VP/tibet_WP_2017")
image18 = ee.Image("users/311605001111/WP-VP/tibet_WP_2018")
image19 = ee.Image("users/311605001111/WP-VP/tibet_WP_2019")
image20 = ee.Image("users/311605001111/WP-VP/tibet_WP_2020")

waterPixel = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12,image13,image14,image15,image16,image17,image18,image19,image20]).sum()
waterPixel13 = ee.ImageCollection([image99,image0,image1,image2,image3,image4,image5,image6,image7,image8,image9,image10,image11,image12]).sum()
waterPixel8 = ee.ImageCollection([image13,image14,image15,image16,image17,image18,image19,image20]).sum()

# %%
# # 大庆市
# roi = ee.Geometry.Rectangle([123.9355, 45.8362,125.3055, 46.8762])
# # 天津市
# roi = ee.Geometry.Rectangle([115.9244, 38.6272,117.4944,39.6372])
# # 武汉市
# roi = ee.Geometry.Rectangle([113.7393, 29.8642,115.0993, 30.9242])
# # 珠三角
# roi = ee.Geometry.Rectangle([112.7614, 22.2347,114.0514, 23.2547])
# 青藏高原
roi = ee.Geometry.Rectangle([89.8826, 34.6579,91.3626, 35.8279])
Map.addLayer(roi, {}, "roi")
Map.centerObject(roi,7)

# %%
waterfrequency = waterPixel.divide(validPixel).rename('frequency')
Map.addLayer(waterfrequency,{'palette':['white','green'],'min':0,'max':1},"water frequency")

dataset_id = 'tibet_WF_' + '9920'
assetID = 'users/311605001111/WF/' + dataset_id
task = ee.batch.Export.image.toAsset(**{
    'image': waterfrequency,
    'description': dataset_id,
    'assetId': assetID,
    'scale': 30,
    'region': roi,
    'maxPixels': 1e13,
})
task.start()

# %% [markdown]
# # 制图 (WF)

# %% [markdown]
# ## our result

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib
from geemap import cartoee

# item = [['region A','daqing'],['region B','tianjin'],['region C','wuhan'],['region D','prd'],['region E','tibet']]
item = [['region A','daqing','(a1)'],['region B','tianjin','(b1)'],['region C','wuhan','(c1)'],['region D','prd','(d1)'],['region E','tibet','(e1)']]

for it in item:
    if it[0] == 'region A':
        re = [125.3055, 45.8362, 123.9355, 46.8762]
    elif it[0] == 'region B':
        re = [117.4944, 38.6272, 115.9244, 39.6372]
    elif it[0] == 'region C':
        re = [115.0993, 29.8642, 113.7393, 30.9242]
    elif it[0] == 'region D':
        re = [114.0514, 22.2347, 112.7614, 23.2547]  
    elif it[0] == 'region E':
        re = [91.3626, 34.6579, 89.8826, 35.8279]
    
    fig = plt.figure(figsize=(12, 8))
    vis = {'min': 0,'max': 1,'palette':['#FFFFFF','#0000FF']}
    pw = ee.Image('users/311605001111/WF/' + it[1] + '_WF_9920').visualize(**vis)
    ax = cartoee.get_map(pw,region=re)
    cartoee.add_gridlines(ax, interval=[0.4,0.3], linestyle=":", ytick_rotation="vertical")
    # cartoee.add_colorbar(ax, vis,cmap = 'Blues',loc="bottom",label="water frequency", orientation="horizontal")
    # ax.set_title(label = it[0] + ' (1999-2020)', fontsize=20)
    ax.tick_params(labelsize=22)
    ax.set_title(label =  it[2] + '     Our result ' + '(' + it[0] + ' / 1999-2020)', fontsize=28)

# %% [markdown]
# ## JRC

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib
from geemap import cartoee

# item = [['region A','daqing'],['region B','tianjin'],['region C','wuhan'],['region D','prd'],['region E','tibet']]
item = [['region A','daqing','(a2)'],['region B','tianjin','(b2)'],['region C','wuhan','(c2)'],['region D','prd','(d2)'],['region E','tibet','(e2)']]
for it in item:
    if it[0] == 'region A':
        re = [125.3055, 45.8362, 123.9355, 46.8762]
    elif it[0] == 'region B':
        re = [117.4944, 38.6272, 115.9244, 39.6372]
    elif it[0] == 'region C':
        re = [115.0993, 29.8642, 113.7393, 30.9242]
    elif it[0] == 'region D':
        re = [114.0514, 22.2347, 112.7614, 23.2547]  
    elif it[0] == 'region E':
        re = [91.3626, 34.6579, 89.8826, 35.8279]
    
    fig = plt.figure(figsize=(12, 8))
    vis = {'min': 0,'max': 100,'palette':['#FFFFFF','#0000FF']}
    pw = ee.Image('users/311605001111/JRC/' + 'JRC_' + it[1] + '_9920').multiply(100).visualize(**vis)
    ax = cartoee.get_map(pw,region=re)
    cartoee.add_gridlines(ax, interval=[0.4,0.3], linestyle=":", ytick_rotation="vertical")
    # cartoee.add_colorbar(ax, vis,cmap = 'Blues',loc="bottom",label="water occurrence", orientation="horizontal", tick_font_size=20, label_font_size=24)
    # ax.set_title(label = it[0] + ' (1999-2020)', fontsize=20)
    ax.tick_params(labelsize=22)
    ax.set_title(label =  it[2] + '     GSWD ' + '(' + it[0] + ' / 1999-2020)', fontsize=28)

# %% [markdown]
# # 制图（PW and SW）

# %% [markdown]
# ## Our result

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib
from geemap import cartoee

# item = [['region A','daqing'],['region B','tianjin'],['region C','wuhan'],['region D','prd'],['region E','tibet']]
item = [['region A','daqing','(a1)'],['region B','tianjin','(b1)'],['region C','wuhan','(c1)'],['region D','prd','(d1)'],['region E','tibet','(e1)']]
for it in item:
    if it[0] == 'region A':
        re = [125.3055, 45.8362, 123.9355, 46.8762]
    elif it[0] == 'region B':
        re = [117.4944, 38.6272, 115.9244, 39.6372]
    elif it[0] == 'region C':
        re = [115.0993, 29.8642, 113.7393, 30.9242]
    elif it[0] == 'region D':
        re = [114.0514, 22.2347, 112.7614, 23.2547]  
    elif it[0] == 'region E':
        re = [91.3626, 34.6579, 89.8826, 35.8279]
    
    fig = plt.figure(figsize=(12, 8))
    vis = {'min': 0,'max': 2,'palette':['#FFFFFF','#87CEFA','#0000FF']}
    
    basemap = ee.Image.constant(0).clip(ee.Geometry.Rectangle(re)).rename('waterclass')
    frequency = ee.Image('users/311605001111/WF/' + it[1] + '_WF_9920')
    permanent = frequency.gte(0.75).remap([0,1],[0,2]).rename('waterclass')
    season= ee.ImageCollection([frequency.gte(0.25),frequency.lt(0.75)]).sum().eq(2).rename('waterclass')
    pw = ee.ImageCollection([permanent,season]).sum().visualize(**vis)
    
    ax = cartoee.get_map(pw,region=re)
    cartoee.add_gridlines(ax, interval=[0.3,0.3], linestyle=":")
    # cartoee.add_colorbar(ax, vis,cmap = 'Blues',loc="right",label="water frequency", orientation="vertical")
    # ax.set_title(label = it[0] + ' (1999-2020)', fontsize=20)
    ax.set_title(label = it[2] + '     Our result ' + '(' + it[0] + ' / 1999-2020)', fontsize=20)

# %% [markdown]
# ## JRC

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib
from geemap import cartoee

# item = [['region A','daqing'],['region B','tianjin'],['region C','wuhan'],['region D','prd'],['region E','tibet']]
item = [['region A','daqing','(a2)'],['region B','tianjin','(b2)'],['region C','wuhan','(c2)'],['region D','prd','(d2)'],['region E','tibet','(e2)']]
for it in item:
    if it[0] == 'region A':
        re = [125.3055, 45.8362, 123.9355, 46.8762]
    elif it[0] == 'region B':
        re = [117.4944, 38.6272, 115.9244, 39.6372]
    elif it[0] == 'region C':
        re = [115.0993, 29.8642, 113.7393, 30.9242]
    elif it[0] == 'region D':
        re = [114.0514, 22.2347, 112.7614, 23.2547]  
    elif it[0] == 'region E':
        re = [91.3626, 34.6579, 89.8826, 35.8279]
    
    fig = plt.figure(figsize=(12, 8))
    vis = {'min': 0,'max': 2,'palette':['#FFFFFF','#87CEFA','#0000FF']}
    
    basemap = ee.Image.constant(0).clip(ee.Geometry.Rectangle(re)).rename('waterclass')
    frequency = ee.Image('users/311605001111/JRC/' + 'JRC_' + it[1] + '_9920')
    permanent = frequency.gte(0.75).remap([0,1],[0,2]).rename('waterclass')
    season= ee.ImageCollection([frequency.gte(0.25),frequency.lt(0.75)]).sum().eq(2).rename('waterclass')
    pw = ee.ImageCollection([permanent,season]).sum().visualize(**vis)
    
    ax = cartoee.get_map(pw,region=re)
    cartoee.add_gridlines(ax, interval=[0.3,0.3], linestyle=":")
    # cartoee.add_colorbar(ax, vis,cmap = 'Blues',loc="right",label="water frequency", orientation="vertical")
    # ax.set_title(label = it[0] + ' (1999-2020)', fontsize=20)
    ax.set_title(label = it[2] + '     GSWD ' + '(' + it[0] + ' / 1999-2020)', fontsize=20)

# %% [markdown]
# ## Maryland

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib
from geemap import cartoee

# item = [['region A','daqing'],['region B','tianjin'],['region C','wuhan'],['region D','prd'],['region E','tibet']]
item = [['region A','daqing','(a3)'],['region B','tianjin','(b3)'],['region C','wuhan','(c3)'],['region D','prd','(d3)'],['region E','tibet','(e3)']]
for it in item:
    if it[0] == 'region A':
        re = [125.3055, 45.8362, 123.9355, 46.8762]
    elif it[0] == 'region B':
        re = [117.4944, 38.6272, 115.9244, 39.6372]
    elif it[0] == 'region C':
        re = [115.0993, 29.8642, 113.7393, 30.9242]
    elif it[0] == 'region D':
        re = [114.0514, 22.2347, 112.7614, 23.2547]  
    elif it[0] == 'region E':
        re = [91.3626, 34.6579, 89.8826, 35.8279]
    
    fig = plt.figure(figsize=(12, 8))
    vis = {'min': 0,'max': 2,'palette':['#FFFFFF','#87CEFA','#0000FF']}
    
    basemap = ee.Image.constant(0).clip(ee.Geometry.Rectangle(re)).rename('waterclass')
    Maryland = ee.Image("users/311605001111/MARYLAND_99-20").clip(ee.Geometry.Rectangle(re)).select('b1').rename('waterclass')
    Maryland_permanent = Maryland.select('waterclass').eq(2).remap([0,1],[0,2]).rename('waterclass')
    Maryland_season= Maryland.select('waterclass').eq(7).rename('waterclass')
    pw = ee.ImageCollection([Maryland_permanent,Maryland_season,basemap]).sum().visualize(**vis)
    
    ax = cartoee.get_map(pw,region=re)
    cartoee.add_gridlines(ax, interval=[0.3,0.3], linestyle=":")
    # cartoee.add_colorbar(ax, vis,cmap = 'Blues',loc="right",label="water frequency", orientation="vertical")
    # ax.set_title(label = it[0] + ' (1999-2020)', fontsize=20)
    ax.set_title(label = 'GLAD ' + '(' + it[0] + ' / 1999-2020)', fontsize=20)
