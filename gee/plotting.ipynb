# %%
import os
os.environ['HTTP_PROXY'] = "http://127.0.0.1:10809"
os.environ['HTTPS_PROXY'] = "http://127.0.0.1:10809"

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
MNDWI_NDVI = [928.9684128044594,952.7147524866792,945.3334193811432,905.8537662994411,888.3464582578854]
JRC = [700.7690358956702,742.8197875795443,739.8565755836654,731.531439573101,725.1956378415728]
JRC_water = [634.4658692132646,648.2288104897715,532.4843085831961,609.0675688837387,603.3918082687443]
Maryland_JRC = [604.3956506682418,633.6277180241852,497.01697544273816,587.1955574269507,585.2151596165876]

# %%
year = [2014,2015,2016,2017,2018]
# plot permanent water and seasonal water(折线图)
plt.figure(figsize=(7,5))
plt.title("Area of Wuhan's permanent Water Yearly", fontsize=17)

my_x_ticks = np.arange(2014,2019,1) 
plt.xticks(my_x_ticks)
plt.xlabel("Year", fontsize=16)
plt.ylabel('Area/km²', fontsize=16)
plt.plot(year,MNDWI_NDVI,'*-b' ,label = 'MNDWI_NDVI')
plt.plot(year, JRC,'^-r' ,label = 'JRC')
plt.plot(year,JRC_water,'*-y' ,label = 'JRC_water')
plt.plot(year, Maryland_JRC,'^--m',label = 'Maryland_JRC')
plt.legend(prop={"size":9})
plt.show()
